# %% [markdown]
# ##DICCIONARIO
#
# Es una colección desordenada, modificables y emparejados.

# %%
my_dict = dict()
other_dict = {}
print(type(my_dict))
print(type(other_dict))

# %% [markdown]
# Una de las características más importantes de los diccionarios es que están emparejados, lo cual significa que siempre se van a componer de una llave y un valor.
#
# key:value

# %%
person = {
    'name' : 'Abdiel',
    'last_name' : 'Hernández',
    'Age' : 19,
    'skills' : ['Javascript', 'react', 'Python', 'switf'],
    'address' : {
        'street' : 'Fco. I. Madero',
        'teléfono' : 7821004745
    }
}

# %% [markdown]
# ##CALCULAR LONGITUD

# %%
print(len(person))

# %% [markdown]
# ##ACCEDER A LOS ELEMENTOS

# %%
print(person['name'])
print(type(person['name']))

print(person['last_name'])
print(type(person['last_name']))

print(person['skills'])
print(type(person['skills']))

print(person['address'])
print(type(person['address']))

# %%
print(person.get('name'))
print(person.get('country'))
print(person.get('skills'))
print(person.get('city'))

# %% [markdown]
# ##AGREGAR NUEVOS CAMPOS

# %%
print(person)
person['country'] = 'Poza Rica'
print(person)
# Out:
# {'name': 'Abdiel', 'last_name': 'Hernández', 'Age': 19, 'skills': ['Javascript', 'react', 'Python', 'switf'], 'address': {'street': 'Fco. I. Madero', 'teléfono': 7821004745}}
# {'name': 'Abdiel', 'last_name': 'Hernández', 'Age': 19, 'skills': ['Javascript', 'react', 'Python', 'switf'], 'address': {'street': 'Fco. I. Madero', 'teléfono': 7821004745}, 'country': 'Poza Rica'}

# %% [markdown]
# ##MODIFICAR NUEVOS CAMPOS

# %%
print(person)
person['last_name'] = 'Martínez'
print(person)
# Out:
# {'name': 'Abdiel', 'last_name': 'Hernández', 'Age': 19, 'skills': ['Javascript', 'react', 'Python', 'switf'], 'address': {'street': 'Fco. I. Madero', 'teléfono': 7821004745}, 'country': 'Poza Rica'}
# {'name': 'Abdiel', 'last_name': 'Martínez', 'Age': 19, 'skills': ['Javascript', 'react', 'Python', 'switf'], 'address': {'street': 'Fco. I. Madero', 'teléfono': 7821004745}, 'country': 'Poza Rica'}

# %% [markdown]
# ##VERIFICAR LLAVES

# %%
print('name' in person)
print('marital_status' in person)
# Out:
# True
# False

# %% [markdown]
# ##ANALIZAR TODAS LAS LLAVES EXISTENTES

# %%
print(person.keys())

# %% [markdown]
# ##ANALIZAR TODOS LOS VALORES EXISTENTES

# %%
print(person.values())
